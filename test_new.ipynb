# %%
# Import required libraries
import os
import warnings
import pandas as pd


from importlib import reload
import trading_processor

# Only run this cell when you need to reload the module after changes
reload(trading_processor)

from trading_processor import (
    process_single_ticker,
    process_all_index_tickers,
    update_spy_data,
    read_index_constituents
)

# Suppress all warnings
warnings.filterwarnings('ignore')

# Define your working directory
new_directory = r"C:\Users\peli\local_script\Local Technical Indicator Data"
subfolder = os.path.join(new_directory, 'security_data')
if not os.path.exists(subfolder):
    os.makedirs(subfolder)

print("Local Data Directory:", subfolder)

def main(option, ticker=None, sheet_name='sp500', yf_data_strategy='full_reload', period='1y', top_n=None, resample_period='W', sector=None):
    # Update SPY data
    update_spy_data(yf_data_strategy=yf_data_strategy, period=period)

    if option == 'single' and ticker:
        constituents = read_index_constituents(sheet_name=sheet_name)
        process_single_ticker(ticker, constituents, yf_data_strategy=yf_data_strategy, period=period, option='single', resample_period=resample_period)
    elif option == 'all':
        process_all_index_tickers(sheet_name, yf_data_strategy=yf_data_strategy, period=period, top_n=top_n, resample_period=resample_period, sector=sector)
    else:
        print("Invalid option. Use 'single' for single ticker or 'all' for all tickers.")






yf_data_strategy_mode = 'no_load'
yf_data_strategy_mode = 'latest_10'


# yf_data_strategy_mode = 'full_reload'



# Example usage:
# To process a single ticker with initial pull:
# main(option='single', ticker='NVDA', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D')
# main(option='single', ticker='PLTR', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D')
# main(option='single', ticker='GOOG', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D')
# main(option='single', ticker='MSFT', yf_data_strategy=yf_data_strategy_mode, period='50y', resample_period='D')
# main(option='single', ticker='WDC', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D')
# main(option='single', ticker='ANSS', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D')
# main(option='single', ticker='LLY', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D')
# main(option='single', ticker='AMZN', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D')
# main(option='single', ticker='NOW', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D')
# main(option='single', ticker='TSLA', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D')
# main(option='single', ticker='AKAM', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D')
# main(option='single', ticker='AAPL', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D')
# main(option='single', ticker='ENPH', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='W')
# main(option='single', ticker='INTC', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D')
# main(option='single', ticker='MCHP', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='W')
# main(option='single', ticker='XLK', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D')
# main(option='single', ticker='SPY', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D')
# main(option='single', ticker='TQQQ', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D')
# main(option='single', ticker='ACN', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D')
# main(option='single', ticker='XLE', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D')
# main(option='single', ticker='XLK', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D')
# main(option='single', ticker='SVOL', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D')
# main(option='single', ticker='IT', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D')
# main(option='single', ticker='ADSK', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D')
# main(option='single', ticker='SMCI', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D')
# main(option='single', ticker='QCOM', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D')
# main(option='single', ticker='XIU.TO', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D')
# main(option='single', ticker='ENB.TO', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D')
# main(option='single', ticker='RY.TO', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D')
# main(option='single', ticker='TD.TO', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D')
# main(option='single', ticker='MSFT', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D')
# main(option='single', ticker='OXY', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D')
# main(option='single', ticker='GEN', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D')
# main(option='single', ticker='ON', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D')
# main(option='single', ticker='HPQ', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D')
# main(option='single', ticker='AMD', yf_data_strategy=yf_data_strategy_mode, period='2y', resample_period='D')
# main(option='single', ticker='HLT', yf_data_strategy=yf_data_strategy_mode, period='2y', resample_period='D')
# main(option='single', ticker='FANG', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D')
# main(option='single', ticker='GEN', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D')
# main(option='single', ticker='TRGP', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D')
# main(option='single', ticker='PANW', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D')
# main(option='single', ticker='KEYS', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D')
# main(option='single', ticker='OXY', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D')
# main(option='single', ticker='QCOM', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D')
# main(option='single', ticker='BABA', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D')
# main(option='single', ticker='TER', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D')
# main(option='single', ticker='AKAM', yf_data_strategy=yf_data_strategy_mode, period='3y', resample_period='D')
# main(option='single', ticker='COO', yf_data_strategy=yf_data_strategy_mode, period='3y', resample_period='D')
# main(option='single', ticker='TJX', yf_data_strategy=yf_data_strategy_mode, period='3y', resample_period='D')
# main(option='single', ticker='TJX', yf_data_strategy=yf_data_strategy_mode, period='3y', resample_period='D')




# main(option='single', ticker='XLK', yf_data_strategy=yf_data_strategy_mode, period='3y', resample_period='D')    # Technology
# main(option='single', ticker='XLE', yf_data_strategy=yf_data_strategy_mode, period='3y', resample_period='D')    # Energy
# main(option='single', ticker='XLF', yf_data_strategy=yf_data_strategy_mode, period='3y', resample_period='D')    # Financials
# main(option='single', ticker='XLV', yf_data_strategy=yf_data_strategy_mode, period='3y', resample_period='D')    # Healthcare
# main(option='single', ticker='XLI', yf_data_strategy=yf_data_strategy_mode, period='3y', resample_period='D')    # Industrials
# main(option='single', ticker='XLP', yf_data_strategy=yf_data_strategy_mode, period='3y', resample_period='D')    # Consumer Staples
# main(option='single', ticker='XLY', yf_data_strategy=yf_data_strategy_mode, period='3y', resample_period='D')    # Consumer Discretionary
# main(option='single', ticker='XLB', yf_data_strategy=yf_data_strategy_mode, period='3y', resample_period='D')    # Materials
# main(option='single', ticker='XLRE', yf_data_strategy=yf_data_strategy_mode, period='3y', resample_period='D')   # Real Estate
# main(option='single', ticker='XLU', yf_data_strategy=yf_data_strategy_mode, period='3y', resample_period='D')    # Utilities
# main(option='single', ticker='XLC', yf_data_strategy=yf_data_strategy_mode, period='3y', resample_period='D')    # Communication Services





# main(option='single', ticker='SPY', yf_data_strategy=yf_data_strategy_mode, period='50y', resample_period='D')
# main(option='single', ticker='QQQ', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D')
# main(option='single', ticker='QQQU', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D')
# main(option='single', ticker='ETHA', yf_data_strategy=yf_data_strategy_mode, period='2y', resample_period='D')

# main(option='single', ticker='CAGG.TO', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D')
# main(option='single', ticker='CCDN.NE', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D')
# main(option='single', ticker='CUSM-B.NE', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D')
# main(option='single', ticker='IEFA', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D')
# main(option='single', ticker='CGBI.TO', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D')
# main(option='single', ticker='IEMG', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D')


# CBAL - CI BALANCED ASSET ALLOCATION ETF
# CA equity: iShares Core S&P/TSX Capped Composite Index ETF (XIC.TO)
# US equity: SPY
# EAFA equity: iShares Core MSCI EAFE ETF (IEFA)
# EM equity: iShares Core MSCI Emerging Markets ETF (IEMG)
# CA bond: Vanguard Canadian Aggregate Bond Index ETF (VAB.TO)
# Global bond: Vanguard Global Aggregate Bond Index ETF (CAD-hedged) (VGAB.NE)

# Equity
# main(option='single', ticker='SPY', yf_data_strategy=yf_data_strategy_mode, period='100y', resample_period='D')
# main(option='single', ticker='XIC.TO', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D')
# main(option='single', ticker='IEFA', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D')
# main(option='single', ticker='IEMG', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D')
# # Bond
# main(option='single', ticker='VAB.TO', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D')
# main(option='single', ticker='VGAB.NE', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D')
# main(option='single', ticker='TLT', yf_data_strategy=yf_data_strategy_mode, period='100y', resample_period='D')


# main(option='all', sheet_name='balanced', yf_data_strategy=yf_data_strategy_mode, period='5y',  sector=None,top_n=None, resample_period='D')





# Regional Equity 
# main(option='single', ticker="SPY", yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D') # US Equity
# main(option='single', ticker='XIC.TO', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D') #  iShares Core S&P/TSX Capped Composite Index ETF (XIC.TO)
# main(option='single', ticker='IEFA', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D') # iShares Core MSCI EAFE ETF (IEFA)
# main(option='single', ticker='IEMG', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D') # iShares Core MSCI Emerging Markets ETF (IEMG)








# main(option='single', ticker='MCHI', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D')


# main(option='single', ticker='IBIT', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D')
# main(option='single', ticker='BTCX-B.TO', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D')

main(option='single', ticker='BTC-USD', yf_data_strategy=yf_data_strategy_mode, period='5y', resample_period='D')
# main(option='single', ticker='ETH-USD', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D')
# main(option='single', ticker='BNB-USD', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D')
# main(option='single', ticker='SOL-USD', yf_data_strategy=yf_data_strategy_mode, period='110y', resample_period='D')
# main(option='single', ticker='DOGE-USD', yf_data_strategy=yf_data_strategy_mode, period='3y', resample_period='D')
# main(option='single', ticker='SHIB-USD', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D')
# main(option='single', ticker='XRP-USD', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D')      # M good
# main(option='single', ticker='STETH-USD', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='M')
# main(option='single', ticker='TRX-USD', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D')
# main(option='single', ticker='SHIB-USD', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D')
# main(option='single', ticker='BCH-USD', yf_data_strategy=yf_data_strategy_mode, period='10y', resample_period='D')







# yf_data_strategy_mode = 'no_load'
yf_data_strategy_mode = 'latest_10'
# yf_data_strategy_mode = 'full_reload'


# To process all tickers with initial pull:
# main(option='all', sheet_name='sp500', yf_data_strategy='no_load', period='1y')

# To process all tickers without initial pull:
# main(option='all', sheet_name='sp500', yf_data_strategy='no_load', period='1y')

# To process the top 5 tickers without initial pull:
# main(option='all', sheet_name='sp500', yf_data_strategy=yf_data_strategy_mode, period='3y',  sector='Information Technology',top_n=None, resample_period='D')
# main(option='all', sheet_name='sp500', yf_data_strategy=yf_data_strategy_mode, period='3y',  sector='Consumer Discretionary',top_n=None, resample_period='D')
# main(option='all', sheet_name='sp500', yf_data_strategy=yf_data_strategy_mode, period='3y',  sector='Communication Services',top_n=None, resample_period='D')

# main(option='all', sheet_name='sp500', yf_data_strategy=yf_data_strategy_mode, period='10y',  sector='Energy',top_n=None, resample_period='D')
# main(option='all', sheet_name='m7', yf_data_strategy=yf_data_strategy_mode, period='10y',  sector=None,top_n=None, resample_period='D')
# main(option='all', sheet_name='US-sectors', yf_data_strategy=yf_data_strategy_mode, period='50y',  sector=None,top_n=None, resample_period='D')
# main(option='all', sheet_name='regional-equities', yf_data_strategy=yf_data_strategy_mode, period='10y',  sector=None,top_n=None, resample_period='D')




# main(option='all', sheet_name='crypto', yf_data_strategy=yf_data_strategy_mode, period='10y',  sector=None,top_n=None, resample_period='D')
# main(option='all', sheet_name='balanced', yf_data_strategy=yf_data_strategy_mode, period='5y',  sector=None,top_n=None, resample_period='D')

# main(option='all', sheet_name='sp500', yf_data_strategy=yf_data_strategy_mode, period='10y',  sector='Information Technology',top_n=2, resample_period='D')
# main(option='all', sheet_name='sp500', yf_data_strategy=yf_data_strategy_mode, period='10y',  sector=None,top_n=None, resample_period='D')


# main(option='all', sheet_name='sp500', yf_data_strategy=yf_data_strategy_mode, period='10y',  sector='Financials',top_n=None, resample_period='M')
# main(option='all', sheet_name='sp500', yf_data_strategy=yf_data_strategy_mode, period='10y',  sector='Consumer Discretionary',top_n=None, resample_period='M')
# main(option='all', sheet_name='sp500', yf_data_strategy=yf_data_strategy_mode)
# Out:
# Local Data Directory: C:\Users\peli\local_script\Local Technical Indicator Data\security_data
# Local Data Directory: C:\Users\peli\local_script\Local Technical Indicator Data\security_data
# Local Data Directory: C:\Users\peli\local_script\Local Technical Indicator Data\security_data
